# %% [markdown]
# <p style="align: center;"><img align=center src="https://cdnb.artstation.com/p/assets/covers/images/060/407/559/large/vahid-ghobadi-arfai-vahid-ghobadi-arfai-lo.jpg?1678483232" width=300 height=320/></p>
# <h3 style="text-align: center;"><b>Семинар №5 ФЭФМ МФТИ</b></h3>

# %% [markdown]
# # Графики

# %%
import matplotlib.pyplot as plt

# %%
x = ['Январь', 'Февраль', 'Март', 'Апрель', 'Май']
y = [31, 28, 31, 30, 31]

plt.bar(x, y, label='Данные с календаря', alpha= 0.1 )
#plt.plot(x, y, color='purple', marker='o', markersize=7)
plt.xlabel('Месяц года')
plt.ylabel('Кол-во дней')
plt.title('Столбчатая диаграмма')
plt.legend(loc='center')
plt.show()

# %%
plt.pie([0.5, 0.5, 0.01], labels = ['No','No, but in orange','Perhaps'])
plt.title('What are the chances that I will wake up early tomorrow?')
plt.show()

# %%
amount = [18, 22 , 19, 19, 20]
groups = ["группа 1", "группа 2", "группа 3", "группа 4", "группа 5"]

plt.pie(amount, labels=groups, autopct='%1.f%%')
plt.title("Распределение студентов по группам")
plt.show()

# %%
amount = [18, 22, 19, 19, 20]
labels = ["группа 1", "группа 2", "группа 3", "группа 4", "группа 5"]
color_ = ["red", "violet", "blue", "pink", "purple"]

plt.pie(amount, labels=labels, colors=color_, autopct='%1.f%%')
plt.title("Распределение студентов по группам")
plt.show()

# %%
import numpy as np

# %%
amount = [18, 22, 19, 19, 20]
labels = ["группа 1", "группа 2", "группа 3", "группа 4", "группа 5"]
colors = plt.cm.viridis(np.linspace(0, 1, len(amount)))

plt.pie(amount, labels=labels, colors=colors, autopct='%.1f%%')
plt.title("Распределение студентов по группам")
plt.show()

# %% [markdown]
# # Аппроксимация

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
x = np.linspace(-5, 5, 30)
y = 2*x**2 + 3*x + 5 + np.random.normal(0, 5, size=len(x))  # добавляем шум

# Аппроксимация полиномом 2-й степени
coeffs = np.polyfit(x, y, deg=2)
poly_func = np.poly1d(coeffs) #превращает найденные коэффициенты в полиномиальную функцию, которую можно использовать как обычную

# Генерация линии аппроксимации
x_fit = np.linspace(min(x), max(x), 200)
y_fit = poly_func(x_fit)

plt.scatter(x, y, label="Данные", color="blue")
plt.plot(x_fit, y_fit, label=f"Аппроксимация: {coeffs[0]:.2f}x² + {coeffs[1]:.2f}x + {coeffs[2]:.2f}", color="red")
plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Сгенерированные данные и аппроксимация")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
x = np.linspace(-5, 5, 30)
y = 2*x**2 + 3*x + 5 + np.random.normal(0, 5, size=len(x)) 

# Аппроксимация полиномом 1-й степени (прямая)
coeffs = np.polyfit(x, y, deg=1)
poly_func = np.poly1d(coeffs)

# Генерация линии аппроксимации
x_fit = np.linspace(min(x), max(x), 200)
y_fit = poly_func(x_fit)

plt.scatter(x, y, label="Данные", color="blue")
plt.plot(x_fit, y_fit, label=f"Аппроксимация: {coeffs[0]:.2f}x + {coeffs[1]:.2f}", color="red")
plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Линейная аппроксимация данных")
plt.grid(True)
plt.show()

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
file_path = r"C:\Users\ok210\Downloads\09.09.2025\09.09.2025\1.csv"
df = pd.read_csv(file_path)

# %%
df2 = pd.read_csv("1.csv")

# %%
print(df.head())
# Out:
#    700.0  0.0022
# 0  699.0  0.0022
# 1  698.0  0.0022
# 2  697.0  0.0022
# 3  696.0  0.0021
# 4  695.0  0.0022

# %%
print(df2.head())
# Out:
#    700.0  0.0022
# 0  699.0  0.0022
# 1  698.0  0.0022
# 2  697.0  0.0022
# 3  696.0  0.0021
# 4  695.0  0.0022

# %%
df3 = pd.read_csv("1.csv", header=None)

# %%
print(df3.head())
# Out:
#        0       1
# 0  700.0  0.0022
# 1  699.0  0.0022
# 2  698.0  0.0022
# 3  697.0  0.0022
# 4  696.0  0.0021

# %%
df3.columns = ["x", "y"]

# %%
print(df3.head())
# Out:
#        x       y
# 0  700.0  0.0022
# 1  699.0  0.0022
# 2  698.0  0.0022
# 3  697.0  0.0022
# 4  696.0  0.0021

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       451 non-null    float64
#  1   y       451 non-null    float64
# dtypes: float64(2)
# memory usage: 7.2 KB
# None

# %% [markdown]
# ![image.png](attachment:05250d20-ddfa-4073-b983-5997ca7be9d7.png)

# %%
print(df3.describe())
# Out:
#                 x           y
# count  451.000000  451.000000
# mean   475.000000    0.030395
# std    130.336743    0.060109
# min    250.000000   -0.001000
# 25%    362.500000    0.001500
# 50%    475.000000    0.002700
# 75%    587.500000    0.023850
# max    700.000000    0.240100

# %%
print(df3.min())
# Out:
# x    250.000
# y     -0.001
# dtype: float64

# %%
df3 = df3.astype("float32")

print(df3.dtypes)
# Out:
# x    float32
# y    float32
# dtype: object

# %%
df3[["x"]] = df3[["x"]].astype("float64")

print(df3.dtypes)
# Out:
# x    float64
# y    float32
# dtype: object

# %% [markdown]
# ![image.png](attachment:48c526af-0251-4bf7-986d-bde615c45192.png)

# %%
print(df3.columns.tolist())
# Out:
# ['x', 'y']

# %%
print(df3.shape)
# Out:
# (451, 2)

# %%
print(df3[df3["y"] > 0.00215])
# Out:
#          x       y
# 0    700.0  0.0022
# 1    699.0  0.0022
# 2    698.0  0.0022
# 3    697.0  0.0022
# 5    695.0  0.0022
# ..     ...     ...
# 446  254.0  0.0387
# 447  253.0  0.0454
# 448  252.0  0.0513
# 449  251.0  0.0636
# 450  250.0  0.1053
#
# [313 rows x 2 columns]

# %%
print(df3[(df3["x"] >= 690) & (df3["x"] <= 700)])
# Out:
#         x       y
# 0   700.0  0.0022
# 1   699.0  0.0022
# 2   698.0  0.0022
# 3   697.0  0.0022
# 4   696.0  0.0021
# 5   695.0  0.0022
# 6   694.0  0.0023
# 7   693.0  0.0022
# 8   692.0  0.0024
# 9   691.0  0.0022
# 10  690.0  0.0022

# %%
df3["y_norm"] = (df3["y"] - df3["y"].min()) / (df3["y"].max() - df3["y"].min())
print(df3.head())
# Out:
#        x       y    y_norm
# 0  700.0  0.0022  0.013273
# 1  699.0  0.0022  0.013273
# 2  698.0  0.0022  0.013273
# 3  697.0  0.0022  0.013273
# 4  696.0  0.0021  0.012858

# %%
import matplotlib.pyplot as plt

plt.plot(df3["x"], df3["y"], label="y(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Зависимость y от x")
plt.grid(True)
plt.legend()
plt.show()

# %%
print(df3.isna().sum())
# Out:
# x         0
# y         0
# y_norm    0
# dtype: int64

# %%
df = pd.read_csv("2.csv")

# %%
print(df.isna().sum())
# Out:
# x     0
# y    58
# dtype: int64

# %%
df_zero = df.fillna(0)

df_mean = df.fillna(df["y"].mean())

df_interp = df.interpolate(method="linear")

df_interp.to_csv("save.csv", index=False) # попробуйте поменять True, False :)

# %%
plt.plot(df_zero["x"], df_zero["y"], label="y(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Зависимость y от x")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(df_mean["x"], df_mean["y"], label="y(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Зависимость y от x")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(df_interp["x"], df_interp["y"], label="y(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Зависимость y от x")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # дальше тема

# %% [markdown]
# # Словари

# %% [raw]
# Словари в Python оформляются фигурными скобками. Внутри них находятся пары «ключ — значение».
# Первым пишется ключ, а затем, через двоеточие, — значение. Сами пары отделяются друг от друга запятыми.

# %%
#В словаре индекс может быть любого неизменяемого типа! Индексы, как и сами хранимые значения, задаются явно:

Days = {
    'Sunday': 0,
    'Monday': 1,
    'Tuesday': 2,
    'Wednessday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6
}

print(Days)

# %%
type (Days)

# %%
my_dict = {
  'Гарри Поттер и философский камень' : 'Джоан Роулинг',
  'Убить пересмешника' : 'Харпер Ли'
}


print(my_dict['Гарри Поттер и философский камень'])

# %%
my_dict['Преступление и наказание'] = 'Фёдор Достоевский'

# %%
print (my_dict)

# %%
del my_dict['Убить пересмешника']

print(my_dict)

# %% [markdown]
# ![image.png](attachment:28e4155d-6bc6-4ed6-91fc-04d92fd25c67.png)

# %%
Capitals = {'Russia': 'Moscow', 'China': 'Beijing', 'USA': 'Washington'}
Capitals2 = dict(Russia = 'Moscow', China = 'Beijing', USA = 'Washington')
Capitals3 = dict([("Russia", "Moscow"), ("China", "Beijing"), ("USA", "Washington")])
Capitals4 = dict(zip(["Russia", "China", "USA"], ["Moscow", "Beijing", "Washington"]))

print(Capitals)
print(Capitals2)
print(Capitals3)
print(Capitals4)

# %%
print('В какой стране вы живете?')
country = input()

if country in Capitals:
    print('Столица вашей страны', Capitals[country])
else:
    print('Как называется столица вашей страны?')
    city = input()
    Capitals[country] = city

# %%
Capitals.update({'Germany': 'Berlin',
                   'France': 'Paris'})

print(Capitals)

# %%
Capitals.items()

# %%
Capitals.values()

# %%
Capitals.keys()

# %%
for key, value in Capitals.items():
        print(key, value)

# %%
Capitals.pop('USA')

# %%
del Capitals['Germany']

# %%
Capitals.get('Russia')
