# %% [markdown]
# <p style="align: center;"><img align=center src="https://cdnb.artstation.com/p/assets/covers/images/060/407/559/large/vahid-ghobadi-arfai-vahid-ghobadi-arfai-lo.jpg?1678483232" width=300 height=320/></p>
# <h3 style="text-align: center;"><b>Семинар №10 ФЭФМ МФТИ</b></h3>

# %% [markdown]
# ![image.png](attachment:703451d4-c819-4fba-94df-965c3719aeba.png)

# %% [markdown]
# ![image.png](attachment:6d77cb7b-7383-42b4-a4a6-39d1b1ee2261.png)

# %% [markdown]
# # ООП

# %% [markdown]
# ![image.png](attachment:90767897-eb21-4b92-8e2a-2b61894db016.png)

# %% [markdown]
# ![image.png](attachment:d4f34843-5380-42c0-8e65-4943ae4886c4.png)

# %% [markdown]
# ![image.png](attachment:98bb5032-dd89-4046-89e1-6c7289ca3c49.png)

# %%
import pygame

pygame.init()
screen = pygame.display.set_mode((400, 300))
pygame.display.set_caption("Двигающийся квадрат")

speed = 0.05
running = True


class MovingSquare:
    def __init__(self, screen, x, y, speed):
        self.screen = screen
        self.x = x
        self.y = y
        self.speed = speed

    def update(self):
        self.x += self.speed
        if self.x > 400:
            self.x = 0

    def draw(self):
        pygame.draw.rect(self.screen, (255, 0, 0), (self.x, self.y, 50, 50))
        
        
x, y1 = 50, 100
x, y2 = 50, 200

square1 = MovingSquare(screen, x, y1, speed)
square2 = MovingSquare(screen, x, y2, speed)


while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    square1.update()
    square2.update()
    screen.fill((255, 255, 255))
    square1.draw()
    square2.draw()
    pygame.display.flip()

pygame.quit()

# %%
import pygame

pygame.init()
screen = pygame.display.set_mode((400, 300))
pygame.display.set_caption("Класс")

class Ball:
    def __init__(self, x, y, radius, color, vx, vy):
        self.x = x
        self.y = y
        self.radius = radius
        self.color = color
        self.vx = vx
        self.vy = vy

    def update(self):
        self.x += self.vx
        self.y += self.vy
        if self.x - self.radius < 0 or self.x + self.radius > 400:
            self.vx = -self.vx
        if self.y - self.radius < 0 or self.y + self.radius > 300:
            self.vy = -self.vy

    def draw(self):
        pygame.draw.circle(screen, self.color, (int(self.x), int(self.y)), self.radius)

balls = [
    Ball(50, 50, 20, (255,0,0), 3, 2),
    Ball(150, 100, 30, (0,0,255), 2, 3)  
]

running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    screen.fill((255, 255, 255))
    for ball in balls:
        ball.update()
        ball.draw()
    pygame.display.flip()

pygame.quit()

# %% [markdown]
# # Структура данных

# %% [markdown]
# ![image.png](attachment:7ae096ba-6af3-4e6a-9594-c49de1bc99e0.png)

# %% [markdown]
# ![image.png](attachment:be3b6f5f-f494-44d5-bcdc-5321ea252927.png)

# %% [markdown]
# ### Односвязный список

# %% [markdown]
# Односвязный список — это линейная и однонаправленная структура данных, в которой данные сохраняются на узлах, и каждый узел связан ссылкой со своим следующим узлом. Каждый узел содержит поле данных и ссылку на следующий узел. Односвязные списки можно перемещать только в одном направлении, тогда как двусвязные списки можно перемещать в обоих направлениях.

# %% [markdown]
# ![image.png](attachment:d768d3b8-564f-4b05-9935-83e7611af33e.png)

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

#data: хранит значение узла
#next: ссылка на следующий узел в списке. Если узел является последним в списке, то next равен None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self, data):
        if not self.head:
            self.head = Node(data)
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = Node(data)

    def print_list(self):
        current = self.head
        while current:
            print(current.data, end=" ")
            current = current.next
        print()


linked_list = LinkedList()
linked_list.insert(1)
linked_list.insert(2)
linked_list.insert(3)
linked_list.print_list()

# %% [raw]
# [1] -> None
#
# current = self.head  current = [1]
# while current.next:  у [1] есть next [2] идём дальше
#     current = current.next  теперь current = [2]
#
# у [2] есть next [3] тогда current = [3]
# у [3].next = None  цикл останавливается

# %% [markdown]
# ### Двухсвязный список

# %% [markdown]
# Двусвязный список — это тип связного списка, в котором каждый узел, помимо значения, содержит указатели на предыдущий и следующий элементы. Это позволяет перебирать элементы как в прямом, так и в обратном порядке.
#
# Одним из основных недостатков двусвязного списка является то, что вам нужно больше места в памяти для хранения одной дополнительной ссылки для каждого узла.

# %% [markdown]
# ![image.png](attachment:6bf1789a-6563-493b-ad9d-0213b7724aef.png)

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert(self, data):
        if not self.head:
            self.head = Node(data)
            self.tail = self.head
        else:
            new_node = Node(data)
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node

    def print_list(self):
        current = self.head
        while current:
            print(current.data, end=" ")
            current = current.next
        print()

    def print_reverse(self):
        current = self.tail
        while current:
            print(current.data, end=" ")
            current = current.prev
        print()

doubly_linked_list = DoublyLinkedList()
doubly_linked_list.insert(1)
doubly_linked_list.insert(2)
doubly_linked_list.insert(3)
doubly_linked_list.print_list() 
doubly_linked_list.print_reverse()
# Out:
# 1 2 3
# 3 2 1

# %% [markdown]
# ### Очередь и стек

# %% [markdown]
# ![image.png](attachment:d904403c-c35d-4f35-9cdb-389752777408.png)

# %% [raw]
# Создаём новый узел
#
# Он указывает (next) на текущую верхушку (self.head)
#
# Новый узел становится новой верхушкой

# %% [raw]
# Берём значение с вершины (self.head.value)
#
# Передвигаем вершину на следующий элемент (self.head.next)
#
# Возвращаем удалённое значение

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self):
        self.head = None

    def push(self, value):
        new_node = Node(value)
        new_node.next = self.head
        self.head = new_node

    def pop(self):
        if self.head is None:
            return None
        value = self.head.value
        self.head = self.head.next
        return value

    def print_stack(self):
        current = self.head
        while current is not None:
            print(current.value, end=" ")
            current = current.next
        print()

stack = Stack()
stack.push(1)
stack.push(2)
stack.push(3)
stack.print_stack()  
stack.pop()  
stack.print_stack() 
stack.pop()  
stack.print_stack()
# Out:
# 3 2 1
# 2 1
# 1

# %% [markdown]
# ![image.png](attachment:bb1aa856-474c-4fba-8d4c-f68f4df0b3b8.png)

# %% [markdown]
# # Асимптотика

# %% [raw]
# f(n) = O(1) константа
# f(n) = O(log(n)) логарифмический рост
# f(n) = O(n) линейный рост
# f(n) = O(n*log(n)) квазилинейный рост
# f(n) = O(n^m) полиномиальный рост
# f(n) = O(2^n) экспоненциальный рост

# %% [raw]
# Асимптотические обозначения:
# Ο нотация;
# Ω нотация;
# θ нотация.
#
# Ο(f(n)) = {g(n), где существует c > 0 и n0 такие, что f(n) ≤ c.g(n) для всех n > n0.}
#
# Ω(f(n)) ≥ {g(n), где существует c > 0 и n0 такие, что g(n) ≤ c.f(n) для всех n > n0.}
#
# θ(f(n)) = {g(n) тогда и только тогда, когда g(n) = Ο(f(n)) и g(n) = Ω(f(n)) для всех n > n0.}

# %% [markdown]
# Допустим, имеется задача поиска элемента в массиве. При полном переборе слева направо:
#
# наилучшая оценка:
# О(1), если искомый элемент окажется в начале списка
#
# наихудшая оценка:
# О(N), если искомый элемент окажется в конце списка
#
# средняя оценка:
# О(N/2)

# %% [markdown]
# ![image.png](attachment:f2a63fda-ea7a-4bae-85de-5e9b4fd3cff1.png)

# %% [markdown]
# https://mipt-cs.github.io/python3-2017-2018/labs/lab17.html

# %% [markdown]
# ![image.png](attachment:b35f9086-62cc-4716-930b-ec8e9ecaac5f.png)

# %% [markdown]
# ![image.png](attachment:4848ae8e-7421-4321-8c4b-7d5e792d0d9f.png)

# %% [raw]
# Python-список — это динамический массив
# внутри хранится массив ссылок на объекты (указателей)
# этот массив может расширяться, если в него добавлять элементы
#
# [ ссылка_1, ссылка_2, ссылка_3, ... ]
# где ссылка_i — это ссылка на настоящий объект (например, число, строку...)

# %% [raw]
# Создание списка
# B = list(A)
# O(len(A))
# Python должен пройти по всему A и скопировать ссылки на все его элементы в новый массив

# %%
A = [[1], [2], [3]]
B = list(A)

for i in range(len(A)):
    print(f"A[{i}] id:", id(A[i]))
    print(f"B[{i}] id:", id(B[i]))
    print()
# Out:
# A[0] id: 2263567182272
# B[0] id: 2263567182272
#
# A[1] id: 2263567177728
# B[1] id: 2263567177728
#
# A[2] id: 2263567179968
# B[2] id: 2263567179968

# %% [raw]
# B.reverse()
# O(N)
# На каждой итерации меняет местами элементы с начала и конца
# Каждый элемент участвует в обмене один раз

# %% [raw]
# B.pop(i)
# O(N)
# Удаляется элемент по индексу
# если i в конце (l.pop()), то O(1)
# если в начале (l.pop(0)), то надо сдвинуть всё, O(N)

# %% [markdown]
# ![image.png](attachment:43e23983-e309-47ff-bec1-1a8c609b737f.png)

# %% [markdown]
# В Python множество — это хэш-таблица
#
# Элементы не хранятся в порядке добавления, могут быть только уникальными!, размещаются в “ячейках” по специальной формуле — хэшу

# %% [markdown]
# поэтому питон просто считает hash(x) и сразу попадает в нужную ячейку в памяти

# %% [markdown]
# ![image.png](attachment:ea1687f2-6d6a-4040-aaa9-e52d004d15cb.png)

# %% [markdown]
# Ключ - любое хэшируемое значение (строка, число, кортеж...)

# %%
A = {
    "кошка": "животное",
    "собачка": "животное",
    "кактус": "растение"
}

# %%
A.values()
# Out:
# dict_values(['животное', 'животное', 'растение'])

# %%
"животное" in A.values()
# Out:
# True

# %% [markdown]
# это уже O(N)

# %% [markdown]
# Потому что .values() возвращает список значений, и Python должен пройти по всем
